# %%
# Employee bonus calculation

# Take user input
years_of_service = int(input("Enter years of service: "))
performance_rating = float(input("Enter performance rating (1.0 to 5.0): "))

# Determine bonus percentage
if performance_rating >= 4.5:
    if years_of_service > 10:
        bonus_percentage = 20
    elif years_of_service > 5:
        bonus_percentage = 15
    else:
        bonus_percentage = 10
elif performance_rating >= 3.5:
    if years_of_service > 10:
        bonus_percentage = 15
    elif years_of_service > 5:
        bonus_percentage = 10
    else:
        bonus_percentage = 5
else:
    bonus_percentage = 0

# Calculate bonus amount
salary = float(input("Enter current salary: "))
bonus_amount = salary * bonus_percentage / 100

print("Bonus Amount: ${:.2f}".format(bonus_amount))
# Out:
# Bonus Amount: $3000.00

# %%
num_list=[1, 2, 3, 4, 3, 5]
print("Original list:", num_list*2)
print("number count:", num_list.count(3))
print("index of number:", num_list.index(2))
# Out:
# Original list: [1, 2, 3, 4, 3, 5, 1, 2, 3, 4, 3, 5]
# number count: 2
# index of number: 1

# %%
tpl=(1,"vinay",5,4);
print("Original tuple:", tpl)
a,b,c,d=tpl
print("Unpacked values of a,b,c,d:", a,b,c,d)
e,*f=tpl
print("Unpacked values of e,f:", e,f)
# Out:
# Original tuple: (1, 'vinay', 5, 4)
# Unpacked values of a,b,c,d: 1 vinay 5 4
# Unpacked values of e,f: 1 ['vinay', 5, 4]
